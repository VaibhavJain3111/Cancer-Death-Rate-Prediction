# %% [markdown]
# ### Import Required libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load dataset using pandas

# %%
# encoding='cp1252' is used for decode the dataset
df=pd.read_csv('cancer_reg.csv',encoding='cp1252')

# %%
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
# Check the information of a dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   TARGET_deathRate         3047 non-null   float64
#  3   incidenceRate            3047 non-null   float64
#  4   medIncome                3047 non-null   int64
#  5   popEst2015               3047 non-null   int64
#  6   povertyPercent           3047 non-null   float64
#  7   studyPerCap              3047 non-null   float64
#  8   binnedInc                3047 non-null   object
#  9   MedianAge                3047 non-null   float64
#  10  MedianAgeMale            3047 non-null   float64
#  11  MedianAgeFemale          3047 non-null   float64
#  12  Geography                3047 non-null   object
#  13  AvgHouseholdSize         3047 non-null   float64
# ...

# %%
# Check description of a dataset
df.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medIncome    popEst2015  povertyPercent  studyPerCap    MedianAge  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
#Check the missing values
df.isna().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# TARGET_deathRate              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2285
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     609
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# ...

# %%
df.corr()
# Out:
#                          avgAnnCount  avgDeathsPerYear  TARGET_deathRate  \
# avgAnnCount                 1.000000          0.939408         -0.143532
# avgDeathsPerYear            0.939408          1.000000         -0.090715
# TARGET_deathRate           -0.143532         -0.090715          1.000000
# incidenceRate               0.073553          0.062690          0.449432
# medIncome                   0.269145          0.223207         -0.428615
# popEst2015                  0.926894          0.977634         -0.120073
# povertyPercent             -0.135694         -0.066918          0.429389
# studyPerCap                 0.082071          0.063488         -0.022285
# MedianAge                  -0.024098         -0.024599          0.004375
# MedianAgeMale              -0.124969         -0.148487         -0.021929
# MedianAgeFemale            -0.122844         -0.144069          0.012048
# AvgHouseholdSize            0.064788          0.086161         -0.036905
# ...

# %%
# PctSomeCol18_24 columns has a 2285 missing values out of 3047 & correlation with other features also less so thats why drop it.
df.drop(columns='PctSomeCol18_24',axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# avgAnnCount                  0
# avgDeathsPerYear             0
# TARGET_deathRate             0
# incidenceRate                0
# medIncome                    0
# popEst2015                   0
# povertyPercent               0
# studyPerCap                  0
# binnedInc                    0
# MedianAge                    0
# MedianAgeMale                0
# MedianAgeFemale              0
# Geography                    0
# AvgHouseholdSize             0
# PercentMarried               0
# PctNoHS18_24                 0
# PctHS18_24                   0
# PctBachDeg18_24              0
# PctHS25_Over                 0
# PctBachDeg25_Over            0
# PctEmployed16_Over         152
# PctUnemployed16_Over         0
# PctPrivateCoverage           0
# PctPrivateCoverageAlone    609
# PctEmpPrivCoverage           0
# PctPublicCoverage            0
# PctPublicCoverageAlone       0
# PctWhite                     0
# PctBlack                     0
# PctAsian                     0
# ...

# %%
sns.displot(df['PctEmployed16_Over'],kde=True)
plt.show()

# %%
# Check a skewness of PctEmployed16_Over column
df['PctEmployed16_Over'].skew()
# Out:
# -0.3876487457653264

# %% [markdown]
# #### PctEmployed16_Over columns data are left skewed so,to fill missing value i use median value of a PctEmployed16_Over columns

# %% [markdown]
# #

# %%
# find out a median value to fill missing value

df['PctEmployed16_Over'].median()
# Out:
# 54.5

# %%
# Fill Median value in PctEmployed16_Over columns using fillna method

df['PctEmployed16_Over'].fillna(value=54.5, inplace=True)

# %%
df.isna().sum()
# Out:
# avgAnnCount                  0
# avgDeathsPerYear             0
# TARGET_deathRate             0
# incidenceRate                0
# medIncome                    0
# popEst2015                   0
# povertyPercent               0
# studyPerCap                  0
# binnedInc                    0
# MedianAge                    0
# MedianAgeMale                0
# MedianAgeFemale              0
# Geography                    0
# AvgHouseholdSize             0
# PercentMarried               0
# PctNoHS18_24                 0
# PctHS18_24                   0
# PctBachDeg18_24              0
# PctHS25_Over                 0
# PctBachDeg25_Over            0
# PctEmployed16_Over           0
# PctUnemployed16_Over         0
# PctPrivateCoverage           0
# PctPrivateCoverageAlone    609
# PctEmpPrivCoverage           0
# PctPublicCoverage            0
# PctPublicCoverageAlone       0
# PctWhite                     0
# PctBlack                     0
# PctAsian                     0
# ...

# %%
#Check a distribution of a PctPrivateCoverageAlone column
sns.displot(df['PctPrivateCoverageAlone'],kde=True)
plt.show()

# %%
# Check a skewness of PctPrivateCoverageAlone column
df['PctPrivateCoverageAlone'].skew()
# Out:
# -0.009914923093151362

# %% [markdown]
# #### PctPrivateCoverageAlone columns are little bit left skewed so,there we can use mean or median value to fill missing values,i used median to fill missing value

# %% [markdown]
# #

# %%
#find out the median value to fill the missing values
df['PctPrivateCoverageAlone'].median()
# Out:
# 48.7

# %%
# Fill Median value in PctPrivateCoverageAlone columns using fillna method
df['PctPrivateCoverageAlone'].fillna(value=48.7,inplace =True)

# %%
df.isna().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# TARGET_deathRate           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# studyPerCap                0
# binnedInc                  0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# Geography                  0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# PctMarriedHouseholds       0
# ...

# %% [markdown]
# #### Now there is no any missing value in my dataset

# %%
#In this dataset Two columns has object data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   TARGET_deathRate         3047 non-null   float64
#  3   incidenceRate            3047 non-null   float64
#  4   medIncome                3047 non-null   int64
#  5   popEst2015               3047 non-null   int64
#  6   povertyPercent           3047 non-null   float64
#  7   studyPerCap              3047 non-null   float64
#  8   binnedInc                3047 non-null   object
#  9   MedianAge                3047 non-null   float64
#  10  MedianAgeMale            3047 non-null   float64
#  11  MedianAgeFemale          3047 non-null   float64
#  12  Geography                3047 non-null   object
#  13  AvgHouseholdSize         3047 non-null   float64
# ...

# %%
# Check value counts of Geography columns
df['Geography'].value_counts()
# Out:
# Kitsap County, Washington            1
# Ralls County, Missouri               1
# Pemiscot County, Missouri            1
# Perry County, Missouri               1
# Pettis County, Missouri              1
#                                     ..
# San Bernardino County, California    1
# Cullman County, Alabama              1
# San Diego County, California         1
# San Francisco County, California     1
# Geary County, Kansas                 1
# Name: Geography, Length: 3047, dtype: int64

# %% [markdown]
# #### Geography & binnedInc columns has not make a sense so i drop it

# %%
df.drop(columns='Geography',axis=1,inplace=True)

# %%
df.drop(columns='binnedInc',inplace=True)

# %%
# Check Correlation between fetures
df.corr()
# Out:
#                          avgAnnCount  avgDeathsPerYear  TARGET_deathRate  \
# avgAnnCount                 1.000000          0.939408         -0.143532
# avgDeathsPerYear            0.939408          1.000000         -0.090715
# TARGET_deathRate           -0.143532         -0.090715          1.000000
# incidenceRate               0.073553          0.062690          0.449432
# medIncome                   0.269145          0.223207         -0.428615
# popEst2015                  0.926894          0.977634         -0.120073
# povertyPercent             -0.135694         -0.066918          0.429389
# studyPerCap                 0.082071          0.063488         -0.022285
# MedianAge                  -0.024098         -0.024599          0.004375
# MedianAgeMale              -0.124969         -0.148487         -0.021929
# MedianAgeFemale            -0.122844         -0.144069          0.012048
# AvgHouseholdSize            0.064788          0.086161         -0.036905
# ...

# %%
# Heatmap for better visualization of correlaton
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Columns they are very less correlared to the others features drop it

# %%
df.drop(columns='BirthRate',inplace=True)

# %%
df.drop(columns='PctOtherRace',inplace=True)

# %%
df.drop(columns='studyPerCap',inplace=True)

# %%
df.drop(columns='MedianAge',inplace=True)

# %%
df.drop(columns='AvgHouseholdSize',inplace=True)

# %%
df.drop(columns='PctNoHS18_24',inplace=True)

# %%
df.drop(columns='PctHS25_Over',inplace=True)

# %%
df.drop(columns='PctHS18_24',inplace=True)

# %%
df.drop(columns='incidenceRate',inplace=True)

# %%
# Check upper five row in a dataset
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  medIncome  popEst2015  \
# 0       1397.0               469             164.9      61898      260131
# 1        173.0                70             161.3      48127       43269
# 2        102.0                50             174.7      49348       21026
# 3        427.0               202             194.8      44243       75882
# 4         57.0                26             144.4      49955       10321
#
#    povertyPercent  MedianAgeMale  MedianAgeFemale  PercentMarried  \
# 0            11.2           36.9             41.7            52.5
# 1            18.6           32.2             33.7            44.5
# 2            14.6           44.0             45.8            54.2
# 3            17.1           42.2             43.4            52.7
# 4            12.5           47.8             48.9            57.8
#
#    PctBachDeg18_24  ...  PctUnemployed16_Over  PctPrivateCoverage  \
# ...

# %%
df.columns
# Out:
# Index(['avgAnnCount', 'avgDeathsPerYear', 'TARGET_deathRate', 'medIncome',
#        'popEst2015', 'povertyPercent', 'MedianAgeMale', 'MedianAgeFemale',
#        'PercentMarried', 'PctBachDeg18_24', 'PctBachDeg25_Over',
#        'PctEmployed16_Over', 'PctUnemployed16_Over', 'PctPrivateCoverage',
#        'PctPrivateCoverageAlone', 'PctEmpPrivCoverage', 'PctPublicCoverage',
#        'PctPublicCoverageAlone', 'PctWhite', 'PctBlack', 'PctAsian',
#        'PctMarriedHouseholds'],
#       dtype='object')

# %%
#Rearrane the Index of TARGET_deathRate
df = df.reindex(columns=['avgAnnCount', 'avgDeathsPerYear','medIncome',
       'popEst2015', 'povertyPercent', 'MedianAgeMale', 'MedianAgeFemale',
       'PercentMarried', 'PctBachDeg18_24', 'PctBachDeg25_Over',
       'PctEmployed16_Over', 'PctUnemployed16_Over', 'PctPrivateCoverage',
       'PctPrivateCoverageAlone', 'PctEmpPrivCoverage', 'PctPublicCoverage',
       'PctPublicCoverageAlone', 'PctWhite', 'PctBlack', 'PctAsian',
       'PctMarriedHouseholds','TARGET_deathRate'])

# %%
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  medIncome  popEst2015  povertyPercent  \
# 0       1397.0               469      61898      260131            11.2
# 1        173.0                70      48127       43269            18.6
# 2        102.0                50      49348       21026            14.6
# 3        427.0               202      44243       75882            17.1
# 4         57.0                26      49955       10321            12.5
#
#    MedianAgeMale  MedianAgeFemale  PercentMarried  PctBachDeg18_24  \
# 0           36.9             41.7            52.5              6.9
# 1           32.2             33.7            44.5              7.5
# 2           44.0             45.8            54.2              9.5
# 3           42.2             43.4            52.7              2.5
# 4           47.8             48.9            57.8              2.0
#
#    PctBachDeg25_Over  ...  PctPrivateCoverage  PctPrivateCoverageAlone  \
# ...

# %% [markdown]
# #### Separate the dependent & independent feature

# %%
X=df.iloc[:,:-1]

# %%
X.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  medIncome  popEst2015  povertyPercent  \
# 0       1397.0               469      61898      260131            11.2
# 1        173.0                70      48127       43269            18.6
# 2        102.0                50      49348       21026            14.6
# 3        427.0               202      44243       75882            17.1
# 4         57.0                26      49955       10321            12.5
#
#    MedianAgeMale  MedianAgeFemale  PercentMarried  PctBachDeg18_24  \
# 0           36.9             41.7            52.5              6.9
# 1           32.2             33.7            44.5              7.5
# 2           44.0             45.8            54.2              9.5
# 3           42.2             43.4            52.7              2.5
# 4           47.8             48.9            57.8              2.0
#
#    PctBachDeg25_Over  ...  PctUnemployed16_Over  PctPrivateCoverage  \
# ...

# %%
X.shape
# Out:
# (3047, 21)

# %%
y=df.iloc[:,-1:]

# %%
y.head()
# Out:
#    TARGET_deathRate
# 0             164.9
# 1             161.3
# 2             174.7
# 3             194.8
# 4             144.4

# %%
y.shape
# Out:
# (3047, 1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
ExtraTreesRegressor()
# Out:
# C:\Users\Win10\AppData\Local\Temp/ipykernel_4996/4227174950.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X,y)
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.0256867  0.03792898 0.06774379 0.02787211 0.06260894 0.03712521
#  0.04501524 0.03848699 0.03103307 0.15701507 0.04745422 0.0474371
#  0.04914074 0.0283607  0.03066845 0.04301178 0.06383986 0.03937094
#  0.04688465 0.03040732 0.04290816]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# #### Split the data into train & test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %% [markdown]
# #### Randomized Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
#create the base model to tune
rf_var = RandomForestRegressor()

# %% [markdown]
# #### Random search of parameters, using 3 fold cross validation

# %%
random_var = RandomizedSearchCV(estimator = rf_var, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
random_var.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:598: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   6.0s
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:598: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   5.3s
# ...

# %%
random_var.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 15,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 20}

# %%
random_var.best_score_
# Out:
# -437.04011819087134

# %%
predictions = random_var.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.show()

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 14.203534674539679
# MSE: 390.1215242411477
# RMSE: 19.751494228061524
